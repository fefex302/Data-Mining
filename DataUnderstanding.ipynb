# %% [markdown]
# # DATA UNDERSTANDING

# %%
import pandas as pd

# %% [markdown]
# # Cyclists dataset

# %%
dataset_cyclists = pd.read_csv("dataset/cyclists.csv")

# %%
dataset_cyclists
# Out:
#                          _url                  name  birth_year  weight  \
# 0                 bruno-surra          Bruno  Surra      1964.0     NaN
# 1                  gerard-rue           Gérard  Rué      1965.0    74.0
# 2                    jan-maas             Jan  Maas      1996.0    69.0
# 3        nathan-van-hooydonck  Nathan Van Hooydonck      1995.0    78.0
# 4            jose-felix-parra     José Félix  Parra      1997.0    55.0
# ...                       ...                   ...         ...     ...
# 6129  juan-jose-martinez-diaz   Juan José  Martínez      1966.0     NaN
# 6130           inigo-elosegui       Iñigo  Elosegui      1998.0    75.0
# 6131           paolo-alberati       Paolo  Alberati      1973.0     NaN
# 6132        jackson-rodriguez    Jackson  Rodríguez      1985.0    58.0
# 6133             ward-vanhoof         Ward  Vanhoof      1999.0    75.0
#
#       height  nationality
# 0        NaN        Italy
# 1      182.0       France
# ...

# %%
dataset_cyclists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6134 entries, 0 to 6133
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _url         6134 non-null   object
#  1   name         6134 non-null   object
#  2   birth_year   6121 non-null   float64
#  3   weight       3078 non-null   float64
#  4   height       3143 non-null   float64
#  5   nationality  6133 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 287.7+ KB

# %%
dataset_cyclists.head()
# Out:
#                    _url                  name  birth_year  weight  height  \
# 0           bruno-surra          Bruno  Surra      1964.0     NaN     NaN
# 1            gerard-rue           Gérard  Rué      1965.0    74.0   182.0
# 2              jan-maas             Jan  Maas      1996.0    69.0   189.0
# 3  nathan-van-hooydonck  Nathan Van Hooydonck      1995.0    78.0   192.0
# 4      jose-felix-parra     José Félix  Parra      1997.0    55.0   171.0
#
#    nationality
# 0        Italy
# 1       France
# 2  Netherlands
# 3      Belgium
# 4        Spain

# %%
dataset_cyclists.shape
# Out:
# (6134, 6)

# %%
dataset_cyclists.select_dtypes(include="number")
# Out:
#       birth_year  weight  height
# 0         1964.0     NaN     NaN
# 1         1965.0    74.0   182.0
# 2         1996.0    69.0   189.0
# 3         1995.0    78.0   192.0
# 4         1997.0    55.0   171.0
# ...          ...     ...     ...
# 6129      1966.0     NaN     NaN
# 6130      1998.0    75.0   188.0
# 6131      1973.0     NaN     NaN
# 6132      1985.0    58.0   170.0
# 6133      1999.0    75.0   186.0
#
# [6134 rows x 3 columns]

# %%
dataset_cyclists.select_dtypes(exclude="number")
# Out:
#                          _url                  name  nationality
# 0                 bruno-surra          Bruno  Surra        Italy
# 1                  gerard-rue           Gérard  Rué       France
# 2                    jan-maas             Jan  Maas  Netherlands
# 3        nathan-van-hooydonck  Nathan Van Hooydonck      Belgium
# 4            jose-felix-parra     José Félix  Parra        Spain
# ...                       ...                   ...          ...
# 6129  juan-jose-martinez-diaz   Juan José  Martínez        Spain
# 6130           inigo-elosegui       Iñigo  Elosegui        Spain
# 6131           paolo-alberati       Paolo  Alberati        Italy
# 6132        jackson-rodriguez    Jackson  Rodríguez    Venezuela
# 6133             ward-vanhoof         Ward  Vanhoof      Belgium
#
# [6134 rows x 3 columns]

# %%
dataset_cyclists.select_dtypes(include="object")
# Out:
#                          _url                  name  nationality
# 0                 bruno-surra          Bruno  Surra        Italy
# 1                  gerard-rue           Gérard  Rué       France
# 2                    jan-maas             Jan  Maas  Netherlands
# 3        nathan-van-hooydonck  Nathan Van Hooydonck      Belgium
# 4            jose-felix-parra     José Félix  Parra        Spain
# ...                       ...                   ...          ...
# 6129  juan-jose-martinez-diaz   Juan José  Martínez        Spain
# 6130           inigo-elosegui       Iñigo  Elosegui        Spain
# 6131           paolo-alberati       Paolo  Alberati        Italy
# 6132        jackson-rodriguez    Jackson  Rodríguez    Venezuela
# 6133             ward-vanhoof         Ward  Vanhoof      Belgium
#
# [6134 rows x 3 columns]

# %%
dataset_cyclists.iloc[:3]
# Out:
#           _url          name  birth_year  weight  height  nationality
# 0  bruno-surra  Bruno  Surra      1964.0     NaN     NaN        Italy
# 1   gerard-rue   Gérard  Rué      1965.0    74.0   182.0       France
# 2     jan-maas     Jan  Maas      1996.0    69.0   189.0  Netherlands

# %%
dataset_cyclists["name"]
# Out:
# 0               Bruno  Surra
# 1                Gérard  Rué
# 2                  Jan  Maas
# 3       Nathan Van Hooydonck
# 4          José Félix  Parra
#                 ...
# 6129     Juan José  Martínez
# 6130         Iñigo  Elosegui
# 6131         Paolo  Alberati
# 6132      Jackson  Rodríguez
# 6133           Ward  Vanhoof
# Name: name, Length: 6134, dtype: object

# %%
dataset_cyclists[["weight","height"]]
# Out:
#       weight  height
# 0        NaN     NaN
# 1       74.0   182.0
# 2       69.0   189.0
# 3       78.0   192.0
# 4       55.0   171.0
# ...      ...     ...
# 6129     NaN     NaN
# 6130    75.0   188.0
# 6131     NaN     NaN
# 6132    58.0   170.0
# 6133    75.0   186.0
#
# [6134 rows x 2 columns]

# %%
dataset_cyclists[dataset_cyclists["height"] == 180]
# Out:
#                        _url                    name  birth_year  weight  \
# 21          fabien-grellier        Fabien  Grellier      1994.0    65.0
# 25             graeme-brown     Graeme Allen  Brown      1979.0    76.0
# 54         dylan-sunderland       Dylan  Sunderland      1996.0    67.0
# 55           corrado-serina         Corrado  Serina      1975.0    73.0
# 74            mads-pedersen          Mads  Pedersen      1995.0    70.0
# ...                     ...                     ...         ...     ...
# 6066      tomasz-marczynski      Tomasz  Marczyński      1984.0    70.0
# 6088  eric-antonio-fagundez  Eric Antonio  Fagúndez      1998.0     NaN
# 6098  aitor-gonzalez-prieto  Aitor  González Prieto      1990.0    69.0
# 6099         mathieu-claude         Mathieu  Claude      1983.0    69.0
# 6110        alessio-taliani        Alessio  Taliani      1990.0    60.0
#
#       height nationality
# 21     180.0      France
# 25     180.0   Australia
# ...

# %%
dataset_cyclists.loc[dataset_cyclists.weight < 70]
# Out:
#                             _url                         name  birth_year  \
# 2                       jan-maas                    Jan  Maas      1996.0
# 4               jose-felix-parra            José Félix  Parra      1997.0
# 5                manuel-penalver             Manuel  Peñalver      1998.0
# 11    jose-angel-gomez-marchante  José Ángel  Gómez Marchante      1980.0
# 12              giuseppe-guerini            Giuseppe  Guerini      1970.0
# ...                          ...                          ...         ...
# 6116          gianmarco-garofoli          Gianmarco  Garofoli      2002.0
# 6121      jacob-hindsgaul-madsen             Jacob  Hindsgaul      2000.0
# 6122               savva-novikov               Savva  Novikov      1999.0
# 6126           johannes-adamietz           Johannes  Adamietz      1998.0
# 6132           jackson-rodriguez           Jackson  Rodríguez      1985.0
#
#       weight  height  nationality
# 2       69.0   189.0  Netherlands
# ...

# %%
dataset_cyclists.loc[dataset_cyclists.weight < 70, "nationality"] = "Italy"

# %% [markdown]
# ## Races dataset

# %%
dataset_races = pd.read_csv("dataset/races.csv")

# %%
dataset_races.info()

# %%
dataset_races.head()

# %%
dataset_races.iloc[:3]

# %%
dataset_races["profile"]
